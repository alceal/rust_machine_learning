// %%
:dep linfa = "0.7.0"
:dep linfa-clustering = "0.7.0"
:dep linfa-nn = "0.7.0"
:dep ndarray = "0.15.6"
:dep plotly = "0.8.4"
:dep polars = { version = "0.39.2", features = ["lazy", "dtype-categorical", "ndarray"] }
:dep rand = "0.8.5"

:dep helper-functions = { path = "../../../projects/helper-functions/" }

// %%
use plotly::{
    common::*,
    layout::*,
    Trace,
};

use polars::prelude::*;

use helper_functions::prelude::*;

// %%
let raw_dataset = LazyCsvReader::new("data/k-means-dataset.csv")
    .finish().unwrap()
    .select([
        col("Feature_1").alias("feature_1"),
        col("Feature_2").alias("feature_2"),
        col("Cluster")
            .cast(DataType::String) // You can cast from numeric to categorical directly
            .cast(DataType::Categorical(None, CategoricalOrdering::default()))
            .alias("cluster")
    ])
    .collect().unwrap();

raw_dataset.head(None)
// Out:
// shape: (10, 3)
// ┌───────────┬───────────┬─────────┐
// │ feature_1 ┆ feature_2 ┆ cluster │
// │ ---       ┆ ---       ┆ ---     │
// │ f64       ┆ f64       ┆ cat     │
// ╞═══════════╪═══════════╪═════════╡
// │ -7.338988 ┆ -7.729954 ┆ 2       │
// │ -7.740041 ┆ -7.264665 ┆ 2       │
// │ -1.686653 ┆ 7.793442  ┆ 0       │
// │ 4.422198  ┆ 3.071947  ┆ 1       │
// │ -8.917752 ┆ -7.888196 ┆ 2       │
// │ 5.497538  ┆ 1.813231  ┆ 1       │
// │ -2.336017 ┆ 9.399604  ┆ 0       │
// │ 5.05281   ┆ 1.409445  ┆ 1       │
// │ -2.988372 ┆ 8.828627  ┆ 0       │
// │ -3.700501 ┆ 9.67084   ┆ 0       │
// └───────────┴───────────┴─────────┘

// %%
let x = "feature_1";
let y = "feature_2";
let group_column = None;
let trace = "scatter";
let opacity = 1.0;

let traces = get_traces(
    x,
    y,
    group_column,
    &raw_dataset,
    trace,
    opacity,
);

let layout = Some(
    Layout::new()
        .title(
            Title::new("K-Means Dataset")
        )
        .x_axis(
            Axis::new()
                .title(Title::new(x))
                .range_mode(RangeMode::ToZero)
        )
        .y_axis(
            Axis::new()
                .title(Title::new(y))
                .range_mode(RangeMode::ToZero)
        )
);

let plot = show_plot(traces, layout);
// Out:
// <div>
//     <div id="q9kDjxNKpTkkpsrfCcz6" class="plotly-graph-div" style="height:100%; width:100%;"></div>
//     <script type="text/javascript">
//         require(['https://cdn.plot.ly/plotly-2.12.1.min.js'], function(Plotly) {
//             Plotly.newPlot(
//                 "q9kDjxNKpTkkpsrfCcz6",
//                 {
//   "data": [
//     {
//       "type": "scatter",
//       "opacity": 1.0,
//       "mode": "markers",
//       "x": [
//         -7.338988090691514,
//         -7.740040556435223,
//         -1.686652710949561,
//         4.422197633000881,
//         -8.917751726329124,
//         5.497538459430121,
//         -2.3360166972015683,
//         5.052810290503726,
//         -2.9883718608980403,
//         -3.7005011202553986,
//         -3.110904235282147,
//         4.996894322193149,
//         -2.300334028047995,
//         -3.9245683651031644,
//         -7.530269760273097,
//         -3.2112507169301026,
//         -8.507169629034433,
//         2.614736249570494,
//         -2.4121200737047097,
//         -1.9223405292524798,
//         -1.3506020440453461,
//         -2.6704833347187593,
//         5.614998569645852,
//         -6.9919552408421,
//         -2.9726153158652124,
//         -6.349823013235987,
//         -7.456398521719603,
//         3.8216581529946287,
//         4.627632063381187,
//         -3.3987120526782735,
//         -3.4997339481834384,
//         -3.5800901211138623,
//         -6.049291374607025,
//         -2.2951038789225464,
//         -8.394818253349822,
//         -2.281737688448621,
//         -6.122638574505919,
//         4.884845407336824,
//         -6.986657551105828,
//         4.981634812005261,
//         5.906789985414724,
//         -2.2516472323299856,
//         -7.3672334152237635,
//         4.5253389909754835,
//         -2.5439093927579934,
//         -2.147802017544336,
//         -6.808060953931878,
//         4.154515288398998,
//         -6.542024529076068,
//         6.225895652373453,
//         4.715683394421828,
//         -6.887599832467887,
//         -6.513028945054422,
//         -1.031303578311234,
//         -5.700330007087444,
//         5.154926522534149,
//         -6.485175048772973,
//         -1.5458214938084285,
//         4.753396181479349,
//         -2.9698363940125376,
//         -6.6440126330427045,
//         6.772912210884368,
//         5.539478711661352,
//         -3.8007463826960324,
//         -7.1285913396303435,
//         3.7414641648797433,
//         3.9214346149756656,
//         -6.1680123130623805,
//         -8.583009630506425,
//         -3.571501336778855,
//         5.9453576433824304,
//         -5.821202704301682,
//         -7.579352699143856,
//         -2.035959998479205,
//         -2.9013057761849077,
//         -6.6091703653714315,
//         -8.947069291191147,
//         3.880746174674403,
//         -3.109836312971555,
//         5.819318956949388,
//         -3.5220287433871738,
//         -2.581207744633084,
//         -6.378710003526889,
//         -2.1779341916491863,
//         5.5903026744141515,
//         -6.043935079086128,
//         -5.711845129491463,
//         -0.6434231119079936,
//         6.405333076509198,
//         -3.8868669910098412,
//         -8.549032472272643,
//         -2.5450236621627016,
//         -6.400647365404878,
//         -1.593795505350676,
//         -3.038957826819789,
//         -7.433276496498452,
//         -7.947247620533864,
//         -2.2493148288043265,
//         -7.642886347693787,
//         -6.466192287927569,
//         4.164933525067145,
//         -2.151410262704467,
//         4.4317565858708265,
//         -1.7181656760097033,
//         -3.348415146275389,
//         -2.267235351486716,
//         -2.1655793334842888,
//         -2.2587047727068734,
//         6.793061293739658,
//         -8.278194764970412,
//         5.326139026602615,
//         -3.2924509153889874,
//         -3.317691225945938,
//         -2.4416694183648264,
//         -2.5226948477906843,
//         4.838938531801571,
//         -7.916873345477726,
//         2.926744307137224,
//         -8.750419112177125,
//         3.6338614547283994,
//         5.159225350469273,
//         4.8639713180385185,
//         -1.106403312116651,
//         -6.303070228095503,
//         -6.547313179171678,
//         -7.007544782632037,
//         -6.265460491107845,
//         -3.186119623358709,
//         -5.842087246893371,
//         -7.409884809523711,
//         -1.4261463798774732,
//         -4.4279688383517914,
//         -2.4174368465172478,
//         -4.234115455565783,
//         -3.9877196134201776,
//         5.144866115208559,
//         4.387310684834941,
//         -7.1495021264446414,
//         -2.5040841664102893,
//         -7.393494108487964,
//         -2.978672008987702,
//         -2.7545857390556208,
//         -4.818879266269283,
//         -2.422150554814579,
//         3.120508870274088,
//         3.9245751269681333,
//         5.452740955067061,
//         -2.2325068237227312,
//         5.917543732016526,
//         -3.189222344631241,
//         -3.417221698573961,
//         -4.914902058234881,
//         4.920870703963134,
//         -8.413741361886892,
//         -2.2130773459881743,
//         3.439582429172325,
//         4.621365700235711,
//         -7.4101283387617976,
//         -6.241034732373896,
//         -3.393055059253883,
//         -5.128942727142494,
//         -7.755245444536027,
//         -5.328475215628747,
//         -5.678413268987326,
//         -2.45098890460675,
//         -6.008502487719578,
//         4.168840530609779,
//         -2.4489674131117236,
//         -1.9872560574358524,
//         -1.6956804056830803,
//         -1.3663748085377296,
//         -3.4286218572865534,
//         3.800156994047325,
//         -2.9557125751197715,
//         3.6583701851801504,
//         4.664389010487044,
//         5.5121994729487795,
//         -2.773854456290706,
//         6.762035033240735,
//         5.2639986532802565,
//         -6.79303740367837,
//         -3.053580347577933,
//         -7.542250950097117,
//         6.272290140159736,
//         5.210769346921269,
//         -9.351271691278559,
//         4.964045188716543,
//         -1.0435488541311961,
//         1.3986114961590288,
//         4.199834349531118,
//         -6.942306288424442,
//         -5.251011645579978,
//         3.81438163943559,
//         -8.486073511408843,
//         3.909512204510965,
//         3.319645629207459,
//         4.620862628325413,
//         6.783822925553427,
//         -3.4838792932800717,
//         -6.697760936092775,
//         -1.7707310430573397,
//         -2.6248459054409907,
//         3.81765844066167,
//         4.050514079283889,
//         -1.6966718006585522,
//         4.950786401826106,
//         -7.865353237486814,
//         -7.526200075393796,
//         4.73687480122082,
//         -2.147561598005116,
//         -2.409546257965109,
//         -7.844550651731375,
//         6.091022444023143,
//         3.378994881893056,
//         -6.831105563206443,
//         -5.377270139055242,
//         -6.246845325044985,
//         -6.30255506397073,
//         -3.746148333930832,
//         -7.154678888302914,
//         -6.050221609967781,
//         2.5159831119182945,
//         -7.635977936435573,
//         -8.184096691656123,
//         -2.496195731174843,
//         3.847358097795401,
//         -7.323920451227382,
//         -5.192485556078705,
//         4.324609591587755,
//         -2.5862993324668544,
//         -1.68713746305826,
//         -5.953449643619629,
//         -2.8519121395795195,
//         -8.062885703817045,
//         4.685450676131915,
//         5.321831807523065,
//         -7.53146329895343,
//         4.618977242263953,
//         -5.234659477649986,
//         -6.945706989798587,
//         -6.589852334254857,
//         4.962597396566191,
//         5.797989709728169,
//         -1.883530275287744,
//         -5.356503113881613,
//         3.0454511774337343,
//         5.330022827939214,
//         4.645122535946284,
//         -6.619904689429788,
//         5.186976217398139,
//         -6.508481317779961,
//         4.531118687771244,
//         -7.472021115390139,
//         6.95453740290161,
//         6.829681769445774,
//         -6.552699817387108,
//         3.7129483646500185,
//         -3.837383671951181,
//         -8.358213436931111,
//         -2.216125149754069,
//         -2.7326604083786012,
//         -1.4781981005567992,
//         -6.802258883503652,
//         -4.059861054118883,
//         5.465295185216132,
//         3.9780923714597134,
//         -6.759331559439371,
//         4.70968092121812,
//         5.387172441351363,
//         -2.7015585878338726,
//         -0.9299848075453587,
//         4.7375549

// %% [markdown]
// ![](plots/plot.png)

// %%
let x = "feature_1";
let y = "feature_2";

let dataset = create_linfa_dataset(
    vec![x],
    Some(y),
    vec![x, y],
    &raw_dataset,
);

// %%
let max_n_iterations = 200;
let tolerance = 1e-5;
let n_clusters = 3;

let model = kmeans_model(
    &dataset,
    n_clusters,
    max_n_iterations,
    tolerance,
);

model
// Out:
// KMeans { centroids: [[4.747103374826418],
//  [-6.8971537521181006],
//  [-2.6199507136625297]], shape=[3, 1], strides=[1, 1], layout=CFcf (0xf), const ndim=2, cluster_count: [100.0, 100.0, 100.0], shape=[3], strides=[1], layout=CFcf (0xf), const ndim=1, inertia: 0.911791517567829, dist_fn: L2Dist }

// %%
let predictions = kmeans_predict(&dataset, &model);
predictions
// Out:
// shape: (300, 1)
// ┌─────────────┐
// │ predictions │
// │ ---         │
// │ i32         │
// ╞═════════════╡
// │ 1           │
// │ 1           │
// │ 2           │
// │ 0           │
// │ 1           │
// │ …           │
// │ 2           │
// │ 0           │
// │ 2           │
// │ 1           │
// │ 1           │
// └─────────────┘

// %%
let final_dataframe = polars::functions::concat_df_horizontal(
    &[raw_dataset.clone(), predictions.clone()]
).unwrap()
.lazy()
.select([col("*").exclude(["cluster"])])
.sort(
    ["predictions"],
    SortMultipleOptions {
        descending: vec![false],
        nulls_last: true,
        ..Default::default()
    }
)
.with_column(
    col("predictions")
        .cast(DataType::String)
        .cast(DataType::Categorical(None, CategoricalOrdering::default()))
)
.rename(["predictions"], ["cluster"])
.collect()
.unwrap();

final_dataframe
// Out:
// shape: (300, 3)
// ┌───────────┬───────────┬─────────┐
// │ feature_1 ┆ feature_2 ┆ cluster │
// │ ---       ┆ ---       ┆ ---     │
// │ f64       ┆ f64       ┆ cat     │
// ╞═══════════╪═══════════╪═════════╡
// │ 4.422198  ┆ 3.071947  ┆ 0       │
// │ 5.497538  ┆ 1.813231  ┆ 0       │
// │ 5.05281   ┆ 1.409445  ┆ 0       │
// │ 4.996894  ┆ 1.28026   ┆ 0       │
// │ 2.614736  ┆ 2.159624  ┆ 0       │
// │ …         ┆ …         ┆ …       │
// │ -3.355991 ┆ 7.499439  ┆ 2       │
// │ -2.185114 ┆ 8.629204  ┆ 2       │
// │ -2.72887  ┆ 9.371399  ┆ 2       │
// │ -3.660191 ┆ 9.389984  ┆ 2       │
// │ -4.116681 ┆ 9.19892   ┆ 2       │
// └───────────┴───────────┴─────────┘

// %%
let x = "feature_1";
let y = "feature_2";
let group_column = Some("cluster");
let trace = "scatter";
let opacity = 1.0;

let traces = get_traces(
    x,
    y,
    group_column,
    &final_dataframe,
    trace,
    opacity,
);

let layout = Some(
    Layout::new()
        .title(
            Title::new("K-Means Predictions")
        )
        .x_axis(
            Axis::new()
                .title(Title::new(x))
                .range_mode(RangeMode::ToZero)
        )
        .y_axis(
            Axis::new()
                .title(Title::new(y))
                .range_mode(RangeMode::ToZero)
        )
        .legend(
            Legend::new()
                .title(Title::new(group_column.unwrap()))
        )
);

show_plot(traces, layout);
// Out:
// <div>
//     <div id="WQAul3dHOSz1HrqDk2kU" class="plotly-graph-div" style="height:100%; width:100%;"></div>
//     <script type="text/javascript">
//         require(['https://cdn.plot.ly/plotly-2.12.1.min.js'], function(Plotly) {
//             Plotly.newPlot(
//                 "WQAul3dHOSz1HrqDk2kU",
//                 {
//   "data": [
//     {
//       "type": "scatter",
//       "name": "0",
//       "opacity": 1.0,
//       "mode": "markers",
//       "x": [
//         4.422197633000881,
//         5.497538459430121,
//         5.052810290503726,
//         4.996894322193149,
//         2.614736249570494,
//         5.614998569645852,
//         3.8216581529946287,
//         4.627632063381187,
//         4.884845407336824,
//         4.981634812005261,
//         5.906789985414724,
//         4.5253389909754835,
//         4.154515288398998,
//         6.225895652373453,
//         4.715683394421828,
//         5.154926522534149,
//         4.753396181479349,
//         6.772912210884368,
//         5.539478711661352,
//         3.7414641648797433,
//         3.9214346149756656,
//         5.9453576433824304,
//         3.880746174674403,
//         5.819318956949388,
//         5.5903026744141515,
//         6.405333076509198,
//         4.164933525067145,
//         4.4317565858708265,
//         6.793061293739658,
//         5.326139026602615,
//         4.838938531801571,
//         2.926744307137224,
//         3.6338614547283994,
//         5.159225350469273,
//         4.8639713180385185,
//         5.144866115208559,
//         4.387310684834941,
//         3.120508870274088,
//         3.9245751269681333,
//         5.452740955067061,
//         5.917543732016526,
//         4.920870703963134,
//         3.439582429172325,
//         4.621365700235711,
//         4.168840530609779,
//         3.800156994047325,
//         3.6583701851801504,
//         4.664389010487044,
//         5.5121994729487795,
//         6.762035033240735,
//         5.2639986532802565,
//         6.272290140159736,
//         5.210769346921269,
//         4.964045188716543,
//         1.3986114961590288,
//         4.199834349531118,
//         3.81438163943559,
//         3.909512204510965,
//         3.319645629207459,
//         4.620862628325413,
//         6.783822925553427,
//         3.81765844066167,
//         4.050514079283889,
//         4.950786401826106,
//         4.73687480122082,
//         6.091022444023143,
//         3.378994881893056,
//         2.5159831119182945,
//         3.847358097795401,
//         4.324609591587755,
//         4.685450676131915,
//         5.321831807523065,
//         4.618977242263953,
//         4.962597396566191,
//         5.797989709728169,
//         3.0454511774337343,
//         5.330022827939214,
//         4.645122535946284,
//         5.186976217398139,
//         4.531118687771244,
//         6.95453740290161,
//         6.829681769445774,
//         3.7129483646500185,
//         5.465295185216132,
//         3.9780923714597134,
//         4.70968092121812,
//         5.387172441351363,
//         4.7375549347769335,
//         4.167946970438668,
//         5.154914103436761,
//         3.8670536216905296,
//         5.08369826437433,
//         6.081152125294217,
//         3.191794494730777,
//         4.7041588553235645,
//         5.593880599721304,
//         4.488093741192518,
//         4.189813364748858,
//         5.803042588383061,
//         3.8108838253060293
//       ],
//       "y": [
//         3.071946535927922,
//         1.813231153977305,
//         1.4094451311367573,
//         1.2802600886800777,
//         2.1596239987101598,
//         1.8261123024385935,
//         4.065556959626193,
//         1.0759153124549004,
//         1.4662265085696022,
//         3.8493405231566182,
//         1.2655002183219513,
//         3.2109859959141938,
//         2.0550438233270545,
//         0.735354185113883,
//         1.2960079724286202,
//         5.825901174595453,
//         2.6353003584617785,
//         0.021081884418230112,
//         2.2804692048173414,
//         2.4650888554472377,
//         1.7597225322288848,
//         1.9941735255734911,
//         2.1235634704169395,
//         1.5039940318360272,
//         1.3962660282783288,
//         2.3781513949016877,
//         1.31984045136702,
//         1.4801687492818991,
//         1.2058221210526825,
//         0.36045381275108035,
//         1.3729528067819374,
//         3.327042058106145,
//         0.7589810711529998,
//         3.5059085969433097,
//         1.9857620847225268,
//         2.8389248781108534,
//         0.7253865019758825,
//         1.4889356110744807,
//         2.652767432875408,
//         2.602798525864344,
//         1.3815982951049022,
//         1.3504701641201382,
//         1.6386684480997835,
//         1.6845110450205936,
//         2.2052196212983683,
//         1.3737770384967098,
//         2.435273158204003,
//         2.471167975186182,
//         2.1565116896790837,
//         3.005634944491879,
//         2.601515193205012,
//         0.5430283059800993,
//         3.108735324121331,
//         1.8430266295730475,
//         0.9487820426064422,
//         2.1039102612268232,
//         1.6517838422877387,
//         2.189628273522707,
//         3.8046284497950857,
//         0.9706403193029232,
//         2.607088706258743,
//         2.2168568954326444,
//         2.8227717809617565,
//         3.448525900890284,
//         2.5683267093776454,
//         2.932440510025939,
//         2.891031630995508,
//         1.447414662259971,
//         1.858433242473833,
//         2.7321389044339996,
//         1.3215693363349148,
//         1.662902927347276,
//         2.090497067249514,
//         1.145938740388409,
//         2.7648323779036676,
//         1.3737946609869591,
//         1.5719492120548957,
//         2.020150277705474,
//         1.7709770315068378,
//         2.3748814060396732,
//         0.10590449134898394,
//         1.1648713985855805,
//         1.913644327878932,
//         2.7866793199413706,
//         2.825603018736956,
//         1.5878560870789717,
//         2.583539949374197,
//         1.2001599000852656,
//         3.062120280908098,
//         2.486955634852941,
//         1.7363510772007231,
//         2.7478037373700688,
//         0.5373075327612926,
//         0.5657059095641768,
//         0.8954249060114259,
//         2.62456093524653,
//         2.5614868904253085,
//         2.5960196162882307,
//         1.983402744960319,
//         1.4129886437437624
//       ]
//     },
//     {
//       "type": "scatter",
//       "name": "1",
//       "opacity": 1.0,
//       "mode": "markers",
//       "x": [
//         -7.338988090691514,
//         -7.740040556435223,
//         -8.917751726329124,
//         -7.530269760273097,
//         -8.507169629034433,
//         -6.9919552408421,
//         -6.349823013235987,
//         -7.456398521719603,
//         -6.049291374607025,
//         -8.394818253349822,
//         -6.122638574505919,
//         -6.986657551105828,
//         -7.3672334152237635,
//         -6.808060953931878,
//         -6.542024529076068,
//         -6.887599832467887,
//         -6.513028945054422,
//         -5.700330007087444,
//         -6.485175048772973,
//         -6.6440126330427045,
//         -7.1285913396303435,
//         -6.1680123130623805,
//         -8.583009630506425,
//         -5.821202704301682,
//         -7.579352699143856,
//         -6.6091703653714315,
//         -8.947069291191147,
//         -6.378710003526889,
//         -6.043935079086128,
//         -5.711845129491463,
//         -8.549032472272643,
//         -6.400647365404878,
//         -7.433276496498452,
//         -7.947247620533864,
//         -7.642886347693787,
//         -6.466192287927569,
//         -8.278194764970412,
//         -7.916873345477726,
//         -8.750419112177125,
//         -6.303070228095503,
//         -6.547313179171678,
//         -7.007544782632037,
//         -6.265460491107845,
//         -5.842087246893371,
//         -7.409884809523711,
//         -7.1495021264446414,
//         -7.393494108487964,
//         -4.818879266269283,
//         -4.914902058234881,
//         -8.413741361886892,
//         -7.4101283387617976,
//         -6.241034732373896,
//         -5.128942727142494,
//         -7.755245444536027,
//         -5.328475215628747,
//         -5.678413268987326,
//         -6.008502487719578,
//         -6.79303740367837,
//         -7.542250950097117,
//         -9.351271691278559,
//         -6.942306288424442,
//         -5.251011645579978,
//         -8.486073511408843,
//         -6.697760936092775,
//         -7.865353237486814,
//         -7.526200075393796,
//         -7.844550651731375,
//         -6.831105563206443,
//         -5.377270139055242,

// %% [markdown]
// ![](plots/plot2.png)
